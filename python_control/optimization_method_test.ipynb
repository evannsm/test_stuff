# %%
import jax.numpy as jnp
from jax import jit, grad, vmap
import matplotlib.pyplot as plt
import numpy as np
from jax import random
from jax import jit, jacfwd, lax, jacrev, hessian

key = random.PRNGKey(0)
print(f"{key = }")
# Out:
# key = Array([0, 0], dtype=uint32)

# %%
def reference_function1(t):
    """Trajectory to track"""
    return 3.0

def reference_function2(t):
    """Trajectory to track"""
    return np.sin(t)

def reference_function3(x10, t):
    """Trajectory to track"""
    return x10 + t

# %%
reffunc = reference_function2

# %%
# Simulation parameters
T = 10.0  # Time Horizon of simulation
SIM_STEP = 0.1  # Time step of simulation
T_lookahead = 0.8  # Time horizon for Control
INTEGRATION_STEP = 0.1
C = jnp.array([[1, 0]])

x10 = 0.0  # initial state
x20 = 0.0  # initial state
x30 = 0.0  # initial state
state0 = jnp.array([x10, x20])
u0 = 0.1
input0 = jnp.array([u0])

# Initial conditions
states = np.zeros((int(T/SIM_STEP), len(state0)))
inputs = np.zeros((int(T/SIM_STEP), len(input0)))
refs = np.zeros((int(T/SIM_STEP), len(input0)))
i = 0
states[i] = state0  # Initial state
inputs[i] = u0  # Initial input
refs[i] = reffunc(0.0+T_lookahead)  # Initial reference

# %%
from jax import debug

# @jit
def dynamics(state, input):
    """Compute the state derivative."""
    x1, x2 = state
    u = input

    x1d = x2**3 + u
    x2d = u + x1**3
        
    # Use jax.debug.print to force JAX to print during execution
    # debug.print("x1d = {x1d}, x2d = {x2d}, x3d = {x3d}", x1d=x1d, x2d=x2d, x3d=x3d)

    return jnp.array([x1d, x2d])


# @jit
def get_next_state(state, u, timestep, key):
    """Update state using the dynamics."""
    key, subkey = random.split(key)
    dxdt = dynamics(state, u)
    x_next = state + dxdt * timestep + 0.001 * random.normal(subkey, (len(state),))
    return x_next, key

# %%
next_state, key = get_next_state(state0, u0, SIM_STEP, key)
print(f"{next_state = }")
print(f"{key = }")
# Out:
# next_state = Array([0.01019308, 0.00947322], dtype=float32)
# key = Array([4146024105,  967050713], dtype=uint32)

# %%
def fwd_euler(state, input, integration_step, integrations_int):
    """Forward Euler integration."""
    def for_function(i, current_state):
        return current_state + dynamics(current_state, input) * integration_step

    pred_state = lax.fori_loop(0, integrations_int, for_function, state)
    return pred_state

def predict_state(state, u, T_lookahead, integration_step):
    """Predict the next state."""
    integrations_int = int(T_lookahead / integration_step)
    pred_state = fwd_euler(state, u, integration_step, integrations_int)
    return pred_state

def predict_output(state, u, T_lookahead, integration_step, C):
    """Predict the output."""
    pred_state = predict_state(state, u, T_lookahead, integration_step)
    return C @ pred_state

# %%
aa = predict_state(state0, u0, T_lookahead, 0.1)
bb = fwd_euler(state0, u0, 0.1, 8)
cc = predict_output(state0, u0, T_lookahead, 0.1, C)
print(f"{aa = }")
print(f"{bb = }")
print(f"{cc = }")
# Out:
# aa = Array([0.0800785, 0.0800785], dtype=float32)
# bb = Array([0.0800785, 0.0800785], dtype=float32)
# cc = Array([0.0800785], dtype=float32)

# %%
# get jacobian of predition with respect to input
# @jit
def get_jac_pred_u(state, last_input, T_lookahead, integration_step, C):
    return jacfwd(predict_output, 1)(state, last_input, T_lookahead, integration_step, C)

# @jit
def NR_tracker(currstate, currinput, ref, T_lookahead, integration_step, C, sim_step):
    """Newton-Raphson method to track the reference trajectory."""
    alpha = 20
    pred = predict_output(currstate, currinput, T_lookahead, integration_step, C)
    dgdu = get_jac_pred_u(currstate, currinput, T_lookahead, integration_step, C)
    dgdu_inv = 1/dgdu if dgdu.shape[0] == 1 else jnp.linalg.inv(dgdu)

    print(f"{pred = }")
    print(f"{ref = }")
    error = (ref - pred)
    print(f"{error = }")

    print(f"{dgdu = }")
    print(f"{dgdu_inv = }")
    NR = dgdu_inv @ error
    print(f"{NR = }")
    udot = alpha * NR
    print(f"{udot = }")

    change_u = udot * sim_step
    print(f"{change_u = }")

    print(f"{currinput = }")
    new_u = currinput + change_u
    print(f"{new_u = }")
    return new_u

# %%
dgdu = get_jac_pred_u(state0, u0, 1.2, 0.01, C)
print(f"{dgdu = }")
# Out:
# dgdu = Array([1.2154784], dtype=float32)

# %%
#@jit
def error_func(state, u, T_lookahead, integration_step, C, ref):
    """Compute the error."""
    pred = predict_output(state, u, T_lookahead, integration_step, C)
    return (ref - pred)**2

#@jit
#get error func derivative wrt input
def get_grad_error_u(state, u, T_lookahead, integration_step, C, ref):
    return jacfwd(error_func, 1)(state, u, T_lookahead, integration_step, C, ref)

#@jit
#get hessian of error func wrt input
def get_hess_error_u(state, u, T_lookahead, integration_step, C, ref):
    return jacfwd(get_grad_error_u, 1)(state, u, T_lookahead, integration_step, C, ref)

# %%
dgdu = get_grad_error_u(state0, u0, T_lookahead, 0.1, C, 3.0)
print(f"{dgdu = }")
hess = get_hess_error_u(state0, u0, T_lookahead, 0.1, C, 3.0)
print(f"{hess = }")
# Out:
# dgdu = Array([-4.6856384], dtype=float32)
# hess = Array([1.0116926], dtype=float32)

# %%
def NR_tracker_2(currstate, currinput, ref, T_lookahead, integration_step, C, sim_step):
    """Newton-Raphson method to track the reference trajectory."""
    alpha = 20
    pred = predict_output(currstate, currinput, T_lookahead, integration_step, C)
    error = error_func(currstate, currinput, T_lookahead, integration_step, C, ref)
    print(f"{pred = }")
    print(f"{ref = }")
    print(f"{error = }")

    dgdu = get_grad_error_u(currstate, currinput, T_lookahead, integration_step, C, ref)
    hess = get_hess_error_u(currstate, currinput, T_lookahead, integration_step, C, ref)
    d2gdu2_inv = jnp.linalg.inv(hess) if hess.shape[0] > 1 else 1/hess
    print(f"{dgdu = }")
    print(f"{hess = }")
    print(f"{d2gdu2_inv = }")


    

    scaling = d2gdu2_inv @ dgdu
    scaling = scaling.reshape(1,)
    print(f"{scaling = }")
    NR = scaling
    udot = -alpha * NR
    print(f"{udot = }")

    change_u = udot * sim_step
    print(f"{change_u = }")

    print(f"{currinput = }")
    new_u = currinput + change_u
    print(f"{new_u = }")
    return new_u

# %%
NR_tracker(state0, u0, 0.08, T_lookahead, 0.1, C, SIM_STEP)
# Out:
# pred = Array([0.0800785], dtype=float32)
# ref = 0.08
# error = Array([-7.850677e-05], dtype=float32)
# dgdu = Array([0.80235696], dtype=float32)
# dgdu_inv = Array([1.2463281], dtype=float32)
# NR = Array(-9.784519e-05, dtype=float32)
# udot = Array(-0.0019569, dtype=float32)
# change_u = Array(-0.00019569, dtype=float32)
# currinput = 0.1
# new_u = Array(0.09980431, dtype=float32)
# Array(0.09980431, dtype=float32)

# %%
NR_tracker_2(state0, u0, 0.08, T_lookahead, 0.1, C, SIM_STEP)
# Out:
# pred = Array([0.0800785], dtype=float32)
# ref = 0.08
# error = Array([6.1633125e-09], dtype=float32)
# dgdu = Array([0.00012598], dtype=float32)
# hess = Array([1.2875608], dtype=float32)
# d2gdu2_inv = Array([0.77666235], dtype=float32)
# scaling = Array([9.7844626e-05], dtype=float32)
# udot = Array([-0.00195689], dtype=float32)
# change_u = Array([-0.00019569], dtype=float32)
# currinput = 0.1
# new_u = Array([0.09980431], dtype=float32)
# Array([0.09980431], dtype=float32)

# %%
# Run simulation
i= 0
for t in jnp.arange(SIM_STEP, T, SIM_STEP):
    print(f"Iteration #{i} at {t} seconds")
    i+=1

    currstate = states[i-1]
    currinput = inputs[i-1].item()
    print(f"{currstate= }, {currinput= }")
    next_state, key = get_next_state(currstate, currinput, SIM_STEP, key)

    ref = reffunc((t+T_lookahead))
    print(f"{ref = }")

    # new_input = NR_tracker(currstate, currinput, ref, T_lookahead, INTEGRATION_STEP, C, SIM_STEP).item()
    new_input = NR_tracker_2(currstate, currinput, ref, T_lookahead, INTEGRATION_STEP, C, SIM_STEP).item()
    print(f"{new_input = }")

    states[i] = next_state
    inputs[i] = new_input
    refs[i] = reffunc(t)
    print(f"\n")
# Out:
# Iteration #0 at 0.10000000149011612 seconds
# currstate= array([0., 0.]), currinput= 0.1
# ref = 0.7833269
# pred = Array([0.0800785], dtype=float32)
# ref = 0.7833269
# error = Array([0.49455836], dtype=float32)
# dgdu = Array([-1.1285125], dtype=float32)
# hess = Array([1.2211138], dtype=float32)
# d2gdu2_inv = Array([0.8189245], dtype=float32)
# scaling = Array([-0.9241665], dtype=float32)
# udot = Array([18.48333], dtype=float32)
# change_u = Array([1.848333], dtype=float32)
# currinput = 0.1
# new_u = Array([1.948333], dtype=float32)
# new_input = 1.9483330249786377
#
#
# Iteration #1 at 0.20000000298023224 seconds
# currstate= array([0.01000871, 0.00995112]), currinput= 1.9483330249786377
# ref = 0.841471
# pred = Array([2.6679351], dtype=float32)
# ref = 0.841471
# error = Array([3.3359714], dtype=float32)
# dgdu = Array([12.1650095], dtype=float32)
# hess = Array([43.453636], dtype=float32)
# d2gdu2_inv = Array([0.02301303], dtype=float32)
# scaling = Array([0.27995378], dtype=float32)
# udot = Array([-5.5990753], dtype=float32)
# change_u = Array([-0.55990756], dtype=float32)
# currinput = 1.9483330249786377
# new_u = Array([1.3884255], dtype=float32)
# new_input = 1.3884254693984985
#
#
# Iteration #2 at 0.30000001192092896 seconds
# currstate= array([0.20395105, 0.20412266]), currinput= 1.3884254693984985
# ref = 0.89120734
# pred = Array([2.066046], dtype=float32)
# ref = 0.89120734
# error = Array([1.3802459], dtype=float32)
# dgdu = Array([6.1413093], dtype=float32)
# hess = Array([23.647423], dtype=float32)
# d2gdu2_inv = Array([0.0422879], dtype=float32)
# scaling = Array([0.2597031], dtype=float32)
# udot = Array([-5.194062], dtype=float32)
# change_u = Array([-0.51940626], dtype=float32)
# currinput = 1.3884254693984985
# new_u = Array([0.8690192], dtype=float32)
# new_input = 0.8690192103385925
#
#
# Iteration #3 at 0.4000000059604645 seconds
# currstate= array([0.34485322, 0.3461253 ]), currinput= 0.8690192103385925
# ref = 0.9320391
# pred = Array([1.4938871], dtype=float32)
# ref = 0.9320391
# error = Array([0.31567317], dtype=float32)
# dgdu = Array([2.1759806], dtype=float32)
# hess = Array([10.502544], dtype=float32)
# d2gdu2_inv = Array([0.09521502], dtype=float32)
# scaling = Array([0.20718604], dtype=float32)
# udot = Array([-4.1437206], dtype=float32)
# change_u = Array([-0.41437206], dtype=float32)
# currinput = 0.8690192103385925
# new_u = Array([0.45464715], dtype=float32)
# new_input = 0.45464715361595154
#
#
# Iteration #4 at 0.5 seconds
# currstate= array([0.43681979, 0.4376117 ]), currinput= 0.45464715361595154
# ref = 0.96355814
# pred = Array([1.0801358], dtype=float32)
# ref = 0.96355814
# error = Array([0.01359036], dtype=float32)
# dgdu = Array([0.35252348], dtype=float32)
# hess = Array([4.968567], dtype=float32)
# d2gdu2_inv = Array([0.20126528], dtype=float32)
# scaling = Array([0.07095073], dtype=float32)
# udot = Array([-1.4190147], dtype=float32)
# change_u = Array([-0.14190148], dtype=float32)
# currinput = 0.45464715361595154
# new_u = Array([0.3127457], dtype=float32)
# new_input = 0.31274569034576416
#
#
# Iteration #5 at 0.6000000238418579 seconds
# currstate= array([0.4904497 , 0.49099532]), currinput= 0.31274569034576416
# ref = 0.98544973
# pred = Array([1.019561], dtype=float32)
# ref = 0.98544973
# error = Array([0.00116358], dtype=float32)
# dgdu = Array([0.10192352], dtype=float32)
# hess = Array([4.578519], dtype=float32)
# d2gdu2_inv = Array([0.21841124], dtype=float32)
# scaling = Array([0.02226124], dtype=float32)
# udot = Array([-0.44522482], dtype=float32)
# change_u = Array([-0.04452248], dtype=float32)
# currinput = 0.31274569034576416
# new_u = Array([0.2682232], dtype=float32)
# new_input = 0.26822319626808167
#
#
# Iteration #6 at 0.7000000476837158 seconds
# currstate= array([0.53655714, 0.53281325]), currinput= 0.26822319626808167
# ref = 0.997495
# pred = Array([1.0863605], dtype=float32)
# ref = 0.997495
# error = Array([0.00789707], dtype=float32)
# dgdu = Array([0.28734037], dtype=float32)
# hess = Array([5.5834303], dtype=float32)
# d2gdu2_inv = Array([0.17910136], dtype=float32)
# scaling = Array([0.05146305], dtype=float32)
# udot = Array([-1.0292611], dtype=float32)
# change_u = Array([-0.10292611], dtype=float32)
# currinput = 0.26822319626808167
# new_u = Array([0.16529709], dtype=float32)
# new_input = 0.16529709100723267
#
#
# Iteration #7 at 0.800000011920929 seconds
# currstate= array([0.57809448, 0.57520634]), currinput= 0.16529709100723267
# ref = 0.9995736
# pred = Array([1.0603348], dtype=float32)
# ref = 0.9995736
# error = Array([0.00369192], dtype=float32)
# dgdu = Array([0.19849913], dtype=float32)
# hess = Array([5.587289], dtype=float32)
# d2gdu2_inv = Array([0.17897768], dtype=float32)
# scaling = Array([0.03552691], dtype=float32)
# udot = Array([-0.71053827], dtype=float32)
# change_u = Array([-0.07105383], dtype=float32)
# currinput = 0.16529709100723267
# new_u = Array([0.09424327], dtype=float32)
# new_input = 0.09424326568841934
#
#
# Iteration #8 at 0.9000000357627869 seconds
# currstate= array([0.61316943, 0.61012703]), currinput= 0.09424326568841934
# ref = 0.9916648
# pred = Array([1.0671608], dtype=float32)
# ref = 0.9916648
# error = Array([0.00569965], dtype=float32)
# dgdu = Array([0.25458091], dtype=float32)
# hess = Array([6.0211444], dtype=float32)
# d2gdu2_inv = Array([0.16608138], dtype=float32)
# scaling = Array([0.04228115], dtype=float32)
# udot = Array([-0.845623], dtype=float32)
# change_u = Array([-0.0845623], dtype=float32)
# currinput = 0.09424326568841934
# new_u = Array([0.00968096], dtype=float32)
# new_input = 0.009680964052677155
#
#
# Iteration #9 at 1.0 seconds
# currstate= array([0.64581382, 0.64195955]), currinput= 0.009680964052677155
# ref = 0.9738476
# pred = Array([1.0451564], dtype=float32)
# ref = 0.9738476
# error = Array([0.00508494], dtype=float32)
# dgdu = Array([0.2424], dtype=float32)
# hess = Array([6.1026583], dtype=float32)
# d2gdu2_inv = Array([0.16386302], dtype=float32)
# scaling = Array([0.0397204], dtype=float32)
# udot = Array([-0.79440796], dtype=float32)
# change_u = Array([-0.07944079], dtype=float32)
# currinput = 0.009680964052677155
# new_u = Array([-0.06975983], dtype=float32)
# new_input = -0.06975983083248138
#
#
# Iteration #10 at 1.100000023841858 seconds
# currstate= array([0.67432308, 0.669994  ]), currinput= -0.06975983083248138
# ref = 0.9463001
# pred = Array([1.0196108], dtype=float32)
# ref = 0.9463001
# error = Array([0.00537445], dtype=float32)
# dgdu = Array([0.24992615], dtype=float32)
# hess = Array([6.149865], dtype=float32)
# d2gdu2_inv = Array([0.1626052], dtype=float32)
# scaling = Array([0.04063929], dtype=float32)
# udot = Array([-0.81278586], dtype=float32)
# change_u = Array([-0.08127858], dtype=float32)
# currinput = -0.06975983083248138
# new_u = Array([-0.15103841], dtype=float32)
# new_input = -0.15103840827941895
#
#
# Iteration #11 at 1.2000000476837158 seconds
# currstate= array([0.69647843, 0.69402343]), currinput= -0.15103840827941895
# ref = 0.9092974
# pred = Array([0.97276956], dtype=float32)
# ref = 0.9092974
# error = Array([0.00402871], dtype=float32)
# dgdu = Array([0.21264845], dtype=float32)
# hess = Array([5.8968606], dtype=float32)
# d2gdu2_inv = Array([0.16958176], dtype=float32)
# scaling = Array([0.0360613], dtype=float32)
# udot = Array([-0.721226], dtype=float32)
# change_u = Array([-0.0721226], dtype=float32)
# currinput = -0.15103840827941895
# new_u = Array([-0.22316101], dtype=float32)
# new_input = -0.2231610119342804
#
#
# Iteration #12 at 1.3000000715255737 seconds
# currstate= array([0.7151379 , 0.71452188]), currinput= -0.2231610119342804
# ref = 0.8632093
# pred = Array([0.9294405], dtype=float32)
# ref = 0.8632093
# error = Array([0.00438657], dtype=float32)
# dgdu = Array([0.21805619], dtype=float32)
# hess = Array([5.7077093], dtype=float32)
# d2gdu2_inv = Array([0.17520164], dtype=float32)
# scaling = Array([0.0382038], dtype=float32)
# udot = Array([-0.76407605], dtype=float32)
# change_u = Array([-0.0764076], dtype=float32)
# currinput = -0.2231610119342804
# new_u = Array([-0.29956862], dtype=float32)
# new_input = -0.29956862330436707
#
#
# Iteration #13 at 1.4000000953674316 seconds
# currstate= array([0.72861671, 0.72901839]), currinput= -0.29956862330436707
# ref = 0.80849636
# pred = Array([0.85970426], dtype=float32)
# ref = 0.80849636
# error = Array([0.00262225], dtype=float32)
# dgdu = Array([0.16141064], dtype=float32)
# hess = Array([5.1714797], dtype=float32)
# d2gdu2_inv = Array([0.19336826], dtype=float32)
# scaling = Array([0.03121169], dtype=float32)
# udot = Array([-0.6242339], dtype=float32)
# change_u = Array([-0.06242339], dtype=float32)
# currinput = -0.29956862330436707
# new_u = Array([-0.361992], dtype=float32)
# new_input = -0.3619920015335083
#
#
# Iteration #14 at 1.5 seconds
# currstate= array([0.73776114, 0.73774266]), currinput= -0.3619920015335083
# ref = 0.74570525
# pred = Array([0.79608023], dtype=float32)
# ref = 0.74570525
# error = Array([0.00253764], dtype=float32)
# dgdu = Array([0.15207042], dtype=float32)
# hess = Array([4.7392316], dtype=float32)
# d2gdu2_inv = Array([0.21100467], dtype=float32)
# scaling = Array([0.03208757], dtype=float32)
# udot = Array([-0.64175135], dtype=float32)
# change_u = Array([-0.06417514], dtype=float32)
# currinput = -0.3619920015335083
# new_u = Array([-0.42616713], dtype=float32)
# new_input = -0.4261671304702759
#
#
# Iteration #15 at 1.600000023841858 seconds
# currstate= array([0.74187869, 0.74303067]), currinput= -0.4261671304702759
# ref = 0.67546314
# pred = Array([0.7180073], dtype=float32)
# ref = 0.67546314
# error = Array([0.00181001], dtype=float32)
# dgdu = Array([0.12126665], dtype=float32)
# hess = Array([4.1977253], dtype=float32)
# d2gdu2_inv = Array([0.23822425], dtype=float32)
# scaling = Array([0.02888866], dtype=float32)
# udot = Array([-0.5777731], dtype=float32)
# change_u = Array([-0.05777731], dtype=float32)
# currinput = -0.4261671304702759
# new_u = Array([-0.48394445], dtype=float32)
# new_input = -0.48394444584846497
#
#
# Iteration #16 at 1.7000000476837158 seconds
# currstate= array([0.7419951 , 0.74205798]), currinput= -0.48394444584846497
# ref = 0.5984722
# pred = Array([0.63703364], dtype=float32)
# ref = 0.5984722
# error = Array([0.00148699], dtype=float32)
# dgdu = Array([0.10317045], dtype=float32)
# hess = Array([3.6843996], dtype=float32)
# d2gdu2_inv = Array([0.27141464], dtype=float32)
# scaling = Array([0.02800197], dtype=float32)
# udot = Array([-0.5600394], dtype=float32)
# change_u = Array([-0.05600394], dtype=float32)
# currinput = -0.48394444584846497
# new_u = Array([-0.5399484], dtype=float32)
# new_input = -0.5399484038352966
#
#
# Iteration #17 at 1.8000000715255737 seconds
# currstate= array([0.73464841, 0.73369861]), currinput= -0.5399484038352966
# ref = 0.51550126
# pred = Array([0.54251087], dtype=float32)
# ref = 0.51550126
# error = Array([0.00072952], dtype=float32)
# dgdu = Array([0.06691253], dtype=float32)
# hess = Array([3.1288617], dtype=float32)
# d2gdu2_inv = Array([0.31960505], dtype=float32)
# scaling = Array([0.02138558], dtype=float32)
# udot = Array([-0.42771167], dtype=float32)
# change_u = Array([-0.04277117], dtype=float32)
# currinput = -0.5399484038352966
# new_u = Array([-0.58271956], dtype=float32)
# new_input = -0.5827195644378662
#
#
# Iteration #18 at 1.9000000953674316 seconds
# currstate= array([0.72004157, 0.7201978 ]), currinput= -0.5827195644378662
# ref = 0.42737985
# pred = Array([0.45504832], dtype=float32)
# ref = 0.42737985
# error = Array([0.00076554], dtype=float32)
# dgdu = Array([0.06382221], dtype=float32)
# hess = Array([2.7103512], dtype=float32)
# d2gdu2_inv = Array([0.36895588], dtype=float32)
# scaling = Array([0.02354758], dtype=float32)
# udot = Array([-0.47095162], dtype=float32)
# change_u = Array([-0.04709516], dtype=float32)
# currinput = -0.5827195644378662
# new_u = Array([-0.62981474], dtype=float32)
# new_input = -0.6298147439956665
#
#
# Iteration #19 at 2.0 seconds
# currstate= array([0.70006645, 0.69883007]), currinput= -0.6298147439956665
# ref = 0.3349882
# pred = Array([0.3560172], dtype=float32)
# ref = 0.3349882
# error = Array([0.00044222], dtype=float32)
# dgdu = Array([0.0448643], dtype=float32)
# hess = Array([2.305038], dtype=float32)
# d2gdu2_inv = Array([0.43383232], dtype=float32)
# scaling = Array([0.01946359], dtype=float32)
# udot = Array([-0.3892717], dtype=float32)
# change_u = Array([-0.03892717], dtype=float32)
# currinput = -0.6298147439956665
# new_u = Array([-0.66874194], dtype=float32)
# new_input = -0.6687419414520264
#
#
# Iteration #20 at 2.0999999046325684 seconds
# currstate= array([0.66954249, 0.66940486]), currinput= -0.6687419414520264
# ref = 0.23924947
# pred = Array([0.25598803], dtype=float32)
# ref = 0.23924947
# error = Array([0.00028018], dtype=float32)
# dgdu = Array([0.03317361], dtype=float32)
# hess = Array([1.981141], dtype=float32)
# d2gdu2_inv = Array([0.5047596], dtype=float32)
# scaling = Array([0.0167447], dtype=float32)
# udot = Array([-0.334894], dtype=float32)
# change_u = Array([-0.0334894], dtype=float32)
# currinput = -0.6687419414520264
# new_u = Array([-0.70223135], dtype=float32)
# new_input = -0.7022313475608826
#
#
# Iteration #21 at 2.200000047683716 seconds
# currstate= array([0.63333207, 0.63397276]), currinput= -0.7022313475608826
# ref = 0.14112
# pred = Array([0.16094162], dtype=float32)
# ref = 0.14112
# error = Array([0.0003929], dtype=float32)
# dgdu = Array([0.03690742], dtype=float32)
# hess = Array([1.7482067], dtype=float32)
# d2gdu2_inv = Array([0.57201475], dtype=float32)
# scaling = Array([0.02111159], dtype=float32)
# udot = Array([-0.42223173], dtype=float32)
# change_u = Array([-0.04222317], dtype=float32)
# currinput = -0.7022313475608826
# new_u = Array([-0.7444545], dtype=float32)
# new_input = -0.7444545030593872
#
#
# Iteration #22 at 2.299999952316284 seconds
# currstate= array([0.58739674, 0.58877128]), currinput= -0.7444545030593872
# ref = 0.04158076
# pred = Array([0.05237076], dtype=float32)
# ref = 0.04158076
# error = Array([0.00011642], dtype=float32)
# dgdu = Array([0.01896902], dtype=float32)
# hess = Array([1.5504528], dtype=float32)
# d2gdu2_inv = Array([0.64497286], dtype=float32)
# scaling = Array([0.0122345], dtype=float32)
# udot = Array([-0.24469009], dtype=float32)
# change_u = Array([-0.02446901], dtype=float32)
# currinput = -0.7444545030593872
# new_u = Array([-0.7689235], dtype=float32)
# new_input = -0.7689235210418701
#
#
# Iteration #23 at 2.3999998569488525 seconds
# currstate= array([0.5330137 , 0.53489459]), currinput= -0.7689235210418701
# ref = -0.05837395
# pred = Array([-0.04305208], dtype=float32)
# ref = -0.05837395
# error = Array([0.00023476], dtype=float32)
# dgdu = Array([0.02589475], dtype=float32)
# hess = Array([1.4323274], dtype=float32)
# d2gdu2_inv = Array([0.6981644], dtype=float32)
# scaling = Array([0.01807879], dtype=float32)
# udot = Array([-0.3615759], dtype=float32)
# change_u = Array([-0.03615759], dtype=float32)
# currinput = -0.7689235210418701
# new_u = Array([-0.8050811], dtype=float32)
# new_input = -0.8050811290740967
#
#
# Iteration #24 at 2.5 seconds
# currstate= array([0.47315067, 0.47306144]), currinput= -0.8050811290740967
# ref = -0.15774564
# pred = Array([-0.14803122], dtype=float32)
# ref = -0.15774564
# error = Array([9.437004e-05], dtype=float32)
# dgdu = Array([0.01600222], dtype=float32)
# hess = Array([1.3575418], dtype=float32)
# d2gdu2_inv = Array([0.73662555], dtype=float32)
# scaling = Array([0.01178764], dtype=float32)
# udot = Array([-0.2357529], dtype=float32)
# change_u = Array([-0.02357529], dtype=float32)
# currinput = -0.8050811290740967
# new_u = Array([-0.82865644], dtype=float32)
# new_input = -0.8286564350128174
#
#
# Iteration #25 at 2.5999999046325684 seconds
# currstate= array([0.40167746, 0.40388134]), currinput= -0.8286564350128174
# ref = -0.25554097
# pred = Array([-0.24959482], dtype=float32)
# ref = -0.25554097
# error = Array([3.5356636e-05], dtype=float32)
# dgdu = Array([0.00972046], dtype=float32)
# hess = Array([1.3357103], dtype=float32)
# d2gdu2_inv = Array([0.74866533], dtype=float32)
# scaling = Array([0.00727737], dtype=float32)
# udot = Array([-0.1455475], dtype=float32)
# change_u = Array([-0.01455475], dtype=float32)
# currinput = -0.8286564350128174
# new_u = Array([-0.8432112], dtype=float32)
# new_input = -0.8432111740112305
#
#
# Iteration #26 at 2.700000047683716 seconds
# currstate= array([0.32724929, 0.32767212]), currinput= -0.8432111740112305
# ref = -0.35078323
# pred = Array([-0.3441007], dtype=float32)
# ref = -0.35078323
# error = Array([4.4656008e-05], dtype=float32)
# dgdu = Array([0.01102356], dtype=float32)
# hess = Array([1.3589953], dtype=float32)
# d2gdu2_inv = Array([0.7358377], dtype=float32)
# scaling = Array([0.00811155], dtype=float32)
# udot = Array([-0.16223103], dtype=float32)
# change_u = Array([-0.0162231], dtype=float32)
# currinput = -0.8432111740112305
# new_u = Array([-0.85943425], dtype=float32)
# new_input = -0.8594342470169067
#
#
# Iteration #27 at 2.799999952316284 seconds
# currstate= array([0.24769051, 0.24619894]), currinput= -0.8594342470169067
# ref = -0.44252035
# pred = Array([-0.44502136], dtype=float32)
# ref = -0.44252035
# error = Array([6.2550553e-06], dtype=float32)
# dgdu = Array([-0.00424011], dtype=float32)
# hess = Array([1.4381666], dtype=float32)
# d2gdu2_inv = Array([0.6953297], dtype=float32)
# scaling = Array([-0.00294828], dtype=float32)
# udot = Array([0.05896553], dtype=float32)
# change_u = Array([0.00589655], dtype=float32)
# currinput = -0.8594342470169067
# new_u = Array([-0.8535377], dtype=float32)
# new_input = -0.8535376787185669
#
#
# Iteration #28 at 2.8999998569488525 seconds
# currstate= array([0.16270319, 0.16213638]), currinput= -0.8535376787185669
# ref = -0.52983594
# pred = Array([-0.53514427], dtype=float32)
# ref = -0.52983594
# error = Array([2.8178369e-05], dtype=float32)
# dgdu = Array([-0.00935874], dtype=float32)
# hess = Array([1.5573026], dtype=float32)
# d2gdu2_inv = Array([0.642136], dtype=float32)
# scaling = Array([-0.00600958], dtype=float32)
# udot = Array([0.12019169], dtype=float32)
# change_u = Array([0.01201917], dtype=float32)
# currinput = -0.8535376787185669
# new_u = Array([-0.8415185], dtype=float32)
# new_input = -0.8415185213088989
#
#
# Iteration #29 at 3.0 seconds
# currstate= array([0.07680134, 0.07731654]), currinput= -0.8415185213088989
# ref = -0.61185783
# pred = Array([-0.6256387], dtype=float32)
# ref = -0.61185783
# error = Array([0.00018991], dtype=float32)
# dgdu = Array([-0.02560597], dtype=float32)
# hess = Array([1.7373464], dtype=float32)
# d2gdu2_inv = Array([0.57559043], dtype=float32)
# scaling = Array([-0.01473855], dtype=float32)
# udot = Array([0.29477102], dtype=float32)
# change_u = Array([0.0294771], dtype=float32)
# currinput = -0.8415185213088989
# new_u = Array([-0.8120414], dtype=float32)
# new_input = -0.8120414018630981
#
#
# Iteration #30 at 3.0999999046325684 seconds
# currstate= array([-0.0086266 , -0.00638782]), currinput= -0.8120414018630981
# ref = -0.687766
# pred = Array([-0.7061963], dtype=float32)
# ref = -0.687766
# error = Array([0.00033968], dtype=float32)
# dgdu = Array([-0.03632417], dtype=float32)
# hess = Array([1.9613903], dtype=float32)
# d2gdu2_inv = Array([0.50984246], dtype=float32)
# scaling = Array([-0.0185196], dtype=float32)
# udot = Array([0.37039208], dtype=float32)
# change_u = Array([0.03703921], dtype=float32)
# currinput = -0.8120414018630981
# new_u = Array([-0.7750022], dtype=float32)
# new_input = -0.7750021815299988
#
#
# Iteration #31 at 3.200000047683716 seconds
# currstate= array([-0.09020492, -0.08789967]), currinput= -0.7750021815299988
# ref = -0.7568025
# pred = Array([-0.78342605], dtype=float32)
# ref = -0.7568025
# error = Array([0.00070881], dtype=float32)
# dgdu = Array([-0.05611099], dtype=float32)
# hess = Array([2.2560117], dtype=float32)
# d2gdu2_inv = Array([0.4432601], dtype=float32)
# scaling = Array([-0.02487176], dtype=float32)
# udot = Array([0.4974352], dtype=float32)
# change_u = Array([0.04974352], dtype=float32)
# currinput = -0.7750021815299988
# new_u = Array([-0.72525865], dtype=float32)
# new_input = -0.7252586483955383
#
#
# Iteration #32 at 3.299999952316284 seconds
# currstate= array([-0.16559324, -0.16501984]), currinput= -0.7252586483955383
# ref = -0.81827706
# pred = Array([-0.84885263], dtype=float32)
# ref = -0.81827706
# error = Array([0.00093487], dtype=float32)
# dgdu = Array([-0.0689352], dtype=float32)
# hess = Array([2.5910985], dtype=float32)
# d2gdu2_inv = Array([0.38593668], dtype=float32)
# scaling = Array([-0.02660462], dtype=float32)
# udot = Array([0.53209245], dtype=float32)
# change_u = Array([0.05320925], dtype=float32)
# currinput = -0.7252586483955383
# new_u = Array([-0.6720494], dtype=float32)
# new_input = -0.6720494031906128
#
#
# Iteration #33 at 3.3999998569488525 seconds
# currstate= array([-0.23697849, -0.23838219]), currinput= -0.6720494031906128
# ref = -0.87157565
# pred = Array([-0.9148214], dtype=float32)
# ref = -0.87157565
# error = Array([0.00187019], dtype=float32)
# dgdu = Array([-0.10490808], dtype=float32)
# hess = Array([3.0281255], dtype=float32)
# d2gdu2_inv = Array([0.3302373], dtype=float32)
# scaling = Array([-0.03464456], dtype=float32)
# udot = Array([0.6928912], dtype=float32)
# change_u = Array([0.06928912], dtype=float32)
# currinput = -0.6720494031906128
# new_u = Array([-0.6027603], dtype=float32)
# new_input = -0.6027603149414062
#
#
# Iteration #34 at 3.5 seconds
# currstate= array([-0.30602759, -0.30616105]), currinput= -0.6027603149414062
# ref = -0.916166
# pred = Array([-0.96593744], dtype=float32)
# ref = -0.916166
# error = Array([0.0024772], dtype=float32)
# dgdu = Array([-0.12896258], dtype=float32)
# hess = Array([3.4741023], dtype=float32)
# d2gdu2_inv = Array([0.28784415], dtype=float32)
# scaling = Array([-0.03712112], dtype=float32)
# udot = Array([0.74242246], dtype=float32)
# change_u = Array([0.07424225], dtype=float32)
# currinput = -0.6027603149414062
# new_u = Array([-0.5285181], dtype=float32)
# new_input = -0.5285180807113647
#
#
# Iteration #35 at 3.5999999046325684 seconds
# currstate= array([-0.3688702 , -0.37005857]), currinput= -0.5285180807113647
# ref = -0.9516021
# pred = Array([-1.010188], dtype=float32)
# ref = -0.9516021
# error = Array([0.00343231], dtype=float32)
# dgdu = Array([-0.16190074], dtype=float32)
# hess = Array([3.9800868], dtype=float32)
# d2gdu2_inv = Array([0.2512508], dtype=float32)
# scaling = Array([-0.04067769], dtype=float32)
# udot = Array([0.81355387], dtype=float32)
# change_u = Array([0.08135539], dtype=float32)
# currinput = -0.5285180807113647
# new_u = Array([-0.4471627], dtype=float32)
# new_input = -0.4471626877784729
#
#
# Iteration #36 at 3.700000047683716 seconds
# currstate= array([-0.4286105 , -0.42884162]), currinput= -0.4471626877784729
# ref = -0.9775301
# pred = Array([-1.0456396], dtype=float32)
# ref = -0.9775301
# error = Array([0.00463891], dtype=float32)
# dgdu = Array([-0.19969463], dtype=float32)
# hess = Array([4.514861], dtype=float32)
# d2gdu2_inv = Array([0.22149076], dtype=float32)
# scaling = Array([-0.04423052], dtype=float32)
# udot = Array([0.88461035], dtype=float32)
# change_u = Array([0.08846103], dtype=float32)
# currinput = -0.4471626877784729
# new_u = Array([-0.35870165], dtype=float32)
# new_input = -0.3587016463279724
#
#
# Iteration #37 at 3.799999952316284 seconds
# currstate= array([-0.48242298, -0.48188385]), currinput= -0.3587016463279724
# ref = -0.99369097
# pred = Array([-1.0642515], dtype=float32)
# ref = -0.99369097
# error = Array([0.00497879], dtype=float32)
# dgdu = Array([-0.216776], dtype=float32)
# hess = Array([4.9700184], dtype=float32)
# d2gdu2_inv = Array([0.2012065], dtype=float32)
# scaling = Array([-0.04361674], dtype=float32)
# udot = Array([0.87233484], dtype=float32)
# change_u = Array([0.08723348], dtype=float32)
# currinput = -0.3587016463279724
# new_u = Array([-0.27146816], dtype=float32)
# new_input = -0.2714681625366211
#
#
# Iteration #38 at 3.8999998569488525 seconds
# currstate= array([-0.5294739 , -0.52772063]), currinput= -0.2714681625366211
# ref = -0.9999232
# pred = Array([-1.0715092], dtype=float32)
# ref = -0.9999232
# error = Array([0.00512456], dtype=float32)
# dgdu = Array([-0.22801307], dtype=float32)
# hess = Array([5.3500223], dtype=float32)
# d2gdu2_inv = Array([0.18691511], dtype=float32)
# scaling = Array([-0.04261909], dtype=float32)
# udot = Array([0.8523818], dtype=float32)
# change_u = Array([0.08523818], dtype=float32)
# currinput = -0.2714681625366211
# new_u = Array([-0.18622997], dtype=float32)
# new_input = -0.18622997403144836
#
#
# Iteration #39 at 4.0 seconds
# currstate= array([-0.57191712, -0.56961918]), currinput= -0.18622997403144836
# ref = -0.9961646
# pred = Array([-1.0742705], dtype=float32)
# ref = -0.9961646
# error = Array([0.00610053], dtype=float32)
# dgdu = Array([-0.25685567], dtype=float32)
# hess = Array([5.733792], dtype=float32)
# d2gdu2_inv = Array([0.17440465], dtype=float32)
# scaling = Array([-0.04479682], dtype=float32)
# udot = Array([0.8959365], dtype=float32)
# change_u = Array([0.08959365], dtype=float32)
# currinput = -0.18622997403144836
# new_u = Array([-0.09663633], dtype=float32)
# new_input = -0.0966363251209259
#
#
# Iteration #40 at 4.099999904632568 seconds
# currstate= array([-0.60911375, -0.60578692]), currinput= -0.0966363251209259
# ref = -0.9824526
# pred = Array([-1.0558674], dtype=float32)
# ref = -0.9824526
# error = Array([0.00538974], dtype=float32)
# dgdu = Array([-0.24457747], dtype=float32)
# hess = Array([5.8674326], dtype=float32)
# d2gdu2_inv = Array([0.1704323], dtype=float32)
# scaling = Array([-0.0416839], dtype=float32)
# udot = Array([0.833678], dtype=float32)
# change_u = Array([0.0833678], dtype=float32)
# currinput = -0.0966363251209259
# new_u = Array([-0.01326852], dtype=float32)
# new_input = -0.013268522918224335
#
#
# Iteration #41 at 4.199999809265137 seconds
# currstate= array([-0.6398285 , -0.63752025]), currinput= -0.013268522918224335
# ref = -0.9589243
# pred = Array([-1.031344], dtype=float32)
# ref = -0.9589243
# error = Array([0.00524462], dtype=float32)
# dgdu = Array([-0.24258266], dtype=float32)
# hess = Array([5.93002], dtype=float32)
# d2gdu2_inv = Array([0.1686335], dtype=float32)
# scaling = Array([-0.04090757], dtype=float32)
# udot = Array([0.8181513], dtype=float32)
# change_u = Array([0.08181513], dtype=float32)
# currinput = -0.013268522918224335
# new_u = Array([0.06854661], dtype=float32)
# new_input = 0.0685466080904007
#
#
# Iteration #42 at 4.300000190734863 seconds
# currstate= array([-0.66766977, -0.66606659]), currinput= 0.0685466080904007
# ref = -0.92581457
# pred = Array([-1.000883], dtype=float32)
# ref = -0.92581457
# error = Array([0.00563527], dtype=float32)
# dgdu = Array([-0.25119177], dtype=float32)
# hess = Array([5.931706], dtype=float32)
# d2gdu2_inv = Array([0.16858557], dtype=float32)
# scaling = Array([-0.04234731], dtype=float32)
# udot = Array([0.8469462], dtype=float32)
# change_u = Array([0.08469462], dtype=float32)
# currinput = 0.0685466080904007
# new_u = Array([0.15324122], dtype=float32)
# new_input = 0.15324121713638306
#
#
# Iteration #43 at 4.400000095367432 seconds
# currstate= array([-0.68968892, -0.68792921]), currinput= 0.15324121713638306
# ref = -0.8834545
# pred = Array([-0.9443079], dtype=float32)
# ref = -0.8834545
# error = Array([0.00370314], dtype=float32)
# dgdu = Array([-0.19824597], dtype=float32)
# hess = Array([5.5637255], dtype=float32)
# d2gdu2_inv = Array([0.17973569], dtype=float32)
# scaling = Array([-0.03563188], dtype=float32)
# udot = Array([0.71263754], dtype=float32)
# change_u = Array([0.07126375], dtype=float32)
# currinput = 0.15324121713638306
# new_u = Array([0.22450498], dtype=float32)
# new_input = 0.2245049774646759
#
#
# Iteration #44 at 4.5 seconds
# currstate= array([-0.70678598, -0.70598233]), currinput= 0.2245049774646759
# ref = -0.83226734
# pred = Array([-0.8951645], dtype=float32)
# ref = -0.83226734
# error = Array([0.00395605], dtype=float32)
# dgdu = Array([-0.20001538], dtype=float32)
# hess = Array([5.3100724], dtype=float32)
# d2gdu2_inv = Array([0.18832135], dtype=float32)
# scaling = Array([-0.03766717], dtype=float32)
# udot = Array([0.75334334], dtype=float32)
# change_u = Array([0.07533433], dtype=float32)
# currinput = 0.2245049774646759
# new_u = Array([0.29983932], dtype=float32)
# new_input = 0.2998393177986145
#
#
# Iteration #45 at 4.599999904632568 seconds
# currstate= array([-0.71949673, -0.71764708]), currinput= 0.2998393177986145
# ref = -0.77276444
# pred = Array([-0.8223651], dtype=float32)
# ref = -0.77276444
# error = Array([0.00246023], dtype=float32)
# dgdu = Array([-0.15034954], dtype=float32)
# hess = Array([4.7750816], dtype=float32)
# d2gdu2_inv = Array([0.2094205], dtype=float32)
# scaling = Array([-0.03148628], dtype=float32)
# udot = Array([0.6297255], dtype=float32)
# change_u = Array([0.06297255], dtype=float32)
# currinput = 0.2998393177986145
# new_u = Array([0.36281186], dtype=float32)
# new_input = 0.3628118634223938
#
#
# Iteration #46 at 4.699999809265137 seconds
# currstate= array([-0.72807044, -0.72572839]), currinput= 0.3628118634223938
# ref = -0.7055403
# pred = Array([-0.75766695], dtype=float32)
# ref = -0.7055403
# error = Array([0.00271719], dtype=float32)
# dgdu = Array([-0.1511568], dtype=float32)
# hess = Array([4.3768945], dtype=float32)
# d2gdu2_inv = Array([0.2284725], dtype=float32)
# scaling = Array([-0.03453517], dtype=float32)
# udot = Array([0.69070345], dtype=float32)
# change_u = Array([0.06907035], dtype=float32)
# currinput = 0.3628118634223938
# new_u = Array([0.4318822], dtype=float32)
# new_input = 0.43188220262527466
#
#
# Iteration #47 at 4.800000190734863 seconds
# currstate= array([-0.73127317, -0.73007131]), currinput= 0.43188220262527466
# ref = -0.63126636
# pred = Array([-0.6726276], dtype=float32)
# ref = -0.63126636
# error = Array([0.00171075], dtype=float32)
# dgdu = Array([-0.11264007], dtype=float32)
# hess = Array([3.826172], dtype=float32)
# d2gdu2_inv = Array([0.2613578], dtype=float32)
# scaling = Array([-0.02943936], dtype=float32)
# udot = Array([0.58878726], dtype=float32)
# change_u = Array([0.05887873], dtype=float32)
# currinput = 0.43188220262527466
# new_u = Array([0.49076092], dtype=float32)
# new_input = 0.4907609224319458
#
#
# Iteration #48 at 4.900000095367432 seconds
# currstate= array([-0.72667778, -0.72492218]), currinput= 0.4907609224319458
# ref = -0.5506853
# pred = Array([-0.58115387], dtype=float32)
# ref = -0.5506853
# error = Array([0.00092833], dtype=float32)
# dgdu = Array([-0.07713535], dtype=float32)
# hess = Array([3.276639], dtype=float32)
# d2gdu2_inv = Array([0.30519077], dtype=float32)
# scaling = Array([-0.023541], dtype=float32)
# udot = Array([0.47081995], dtype=float32)
# change_u = Array([0.047082], dtype=float32)
# currinput = 0.4907609224319458
# new_u = Array([0.5378429], dtype=float32)
# new_input = 0.5378429293632507
#
#
# Iteration #49 at 5.0 seconds
# currstate= array([-0.71594018, -0.7145853 ]), currinput= 0.5378429293632507
# ref = -0.46460202
# pred = Array([-0.49569473], dtype=float32)
# ref = -0.46460202
# error = Array([0.00096676], dtype=float32)
# dgdu = Array([-0.07346585], dtype=float32)
# hess = Array([2.8519042], dtype=float32)
# d2gdu2_inv = Array([0.35064292], dtype=float32)
# scaling = Array([-0.02576028], dtype=float32)
# udot = Array([0.5152056], dtype=float32)
# change_u = Array([0.05152056], dtype=float32)
# currinput = 0.5378429293632507
# new_u = Array([0.5893635], dtype=float32)
# new_input = 0.5893635153770447
#
#
# Iteration #50 at 5.099999904632568 seconds
# currstate= array([-0.6975832 , -0.69867468]), currinput= 0.5893635153770447
# ref = -0.37387657
# pred = Array([-0.39635012], dtype=float32)
# ref = -0.37387657
# error = Array([0.00050506], dtype=float32)
# dgdu = Array([-0.04916648], dtype=float32)
# hess = Array([2.4272768], dtype=float32)
# d2gdu2_inv = Array([0.41198432], dtype=float32)
# scaling = Array([-0.02025582], dtype=float32)
# udot = Array([0.40511638], dtype=float32)
# change_u = Array([0.04051164], dtype=float32)
# currinput = 0.5893635153770447
# new_u = Array([0.6298752], dtype=float32)
# new_input = 0.6298751831054688
#
#
# Iteration #51 at 5.199999809265137 seconds
# currstate= array([-0.67347252, -0.67485529]), currinput= 0.6298751831054688
# ref = -0.2794155
# pred = Array([-0.30365318], dtype=float32)
# ref = -0.2794155
# error = Array([0.00058747], dtype=float32)
# dgdu = Array([-0.04945009], dtype=float32)
# hess = Array([2.1095903], dtype=float32)
# d2gdu2_inv = Array([0.4740257], dtype=float32)
# scaling = Array([-0.02344061], dtype=float32)
# udot = Array([0.4688123], dtype=float32)
# change_u = Array([0.04688123], dtype=float32)
# currinput = 0.6298751831054688
# new_u = Array([0.6767564], dtype=float32)
# new_input = 0.6767563819885254
#
#
# Iteration #52 at 5.300000190734863 seconds
# currstate= array([-0.64243126, -0.64158762]), currinput= 0.6767563819885254
# ref = -0.18216212
# pred = Array([-0.1993441], dtype=float32)
# ref = -0.18216212
# error = Array([0.00029522], dtype=float32)
# dgdu = Array([-0.03265244], dtype=float32)
# hess = Array([1.8201543], dtype=float32)
# d2gdu2_inv = Array([0.54940397], dtype=float32)
# scaling = Array([-0.01793938], dtype=float32)
# udot = Array([0.35878763], dtype=float32)
# change_u = Array([0.03587876], dtype=float32)
# currinput = 0.6767563819885254
# new_u = Array([0.71263516], dtype=float32)
# new_input = 0.7126351594924927
#
#
# Iteration #53 at 5.400000095367432 seconds
# currstate= array([-0.60087281, -0.59999442]), currinput= 0.7126351594924927
# ref = -0.08308912
# pred = Array([-0.09959511], dtype=float32)
# ref = -0.08308912
# error = Array([0.00027245], dtype=float32)
# dgdu = Array([-0.0295856], dtype=float32)
# hess = Array([1.6158249], dtype=float32)
# d2gdu2_inv = Array([0.6188789], dtype=float32)
# scaling = Array([-0.0183099], dtype=float32)
# udot = Array([0.3661981], dtype=float32)
# change_u = Array([0.03661981], dtype=float32)
# currinput = 0.7126351594924927
# new_u = Array([0.74925494], dtype=float32)
# new_input = 0.7492549419403076
#
#
# Iteration #54 at 5.5 seconds
# currstate= array([-0.55072606, -0.54943639]), currinput= 0.7492549419403076
# ref = 0.016814092
# pred = Array([0.00382554], dtype=float32)
# ref = 0.016814092
# error = Array([0.0001687], dtype=float32)
# dgdu = Array([-0.02221173], dtype=float32)
# hess = Array([1.4666725], dtype=float32)
# d2gdu2_inv = Array([0.68181545], dtype=float32)
# scaling = Array([-0.0151443], dtype=float32)
# udot = Array([0.30288607], dtype=float32)
# change_u = Array([0.03028861], dtype=float32)
# currinput = 0.7492549419403076
# new_u = Array([0.7795435], dtype=float32)
# new_input = 0.7795435190200806
#
#
# Iteration #55 at 5.599999904632568 seconds
# currstate= array([-0.49284577, -0.49218059]), currinput= 0.7795435190200806
# ref = 0.1165493
# pred = Array([0.10323812], dtype=float32)
# ref = 0.1165493
# error = Array([0.00017719], dtype=float32)
# dgdu = Array([-0.02208309], dtype=float32)
# hess = Array([1.3781711], dtype=float32)
# d2gdu2_inv = Array([0.7255993], dtype=float32)
# scaling = Array([-0.01602348], dtype=float32)
# udot = Array([0.3204695], dtype=float32)
# change_u = Array([0.03204695], dtype=float32)
# currinput = 0.7795435190200806
# new_u = Array([0.8115905], dtype=float32)
# new_input = 0.8115904927253723
#
#
# Iteration #56 at 5.699999809265137 seconds
# currstate= array([-0.42841107, -0.42806035]), currinput= 0.8115904927253723
# ref = 0.21511999
# pred = Array([0.20564228], dtype=float32)
# ref = 0.21511999
# error = Array([8.9826885e-05], dtype=float32)
# dgdu = Array([-0.01550191], dtype=float32)
# hess = Array([1.3374513], dtype=float32)
# d2gdu2_inv = Array([0.74769074], dtype=float32)
# scaling = Array([-0.01159063], dtype=float32)
# udot = Array([0.23181261], dtype=float32)
# change_u = Array([0.02318126], dtype=float32)
# currinput = 0.8115904927253723
# new_u = Array([0.83477175], dtype=float32)
# new_input = 0.8347717523574829
#
#
# Iteration #57 at 5.800000190734863 seconds
# currstate= array([-0.35569721, -0.35538566]), currinput= 0.8347717523574829
# ref = 0.31154174
# pred = Array([0.3060026], dtype=float32)
# ref = 0.31154174
# error = Array([3.068217e-05], dtype=float32)
# dgdu = Array([-0.00908684], dtype=float32)
# hess = Array([1.3445772], dtype=float32)
# d2gdu2_inv = Array([0.7437282], dtype=float32)
# scaling = Array([-0.00675814], dtype=float32)
# udot = Array([0.13516276], dtype=float32)
# change_u = Array([0.01351628], dtype=float32)
# currinput = 0.8347717523574829
# new_u = Array([0.848288], dtype=float32)
# new_input = 0.8482879996299744
#
#
# Iteration #58 at 5.900000095367432 seconds
# currstate= array([-0.27670982, -0.27712417]), currinput= 0.8482879996299744
# ref = 0.40485018
# pred = Array([0.4035775], dtype=float32)
# ref = 0.40485018
# error = Array([1.6197102e-06], dtype=float32)
# dgdu = Array([-0.00212877], dtype=float32)
# hess = Array([1.3984764], dtype=float32)
# d2gdu2_inv = Array([0.7150639], dtype=float32)
# scaling = Array([-0.00152221], dtype=float32)
# udot = Array([0.03044416], dtype=float32)
# change_u = Array([0.00304442], dtype=float32)
# currinput = 0.8482879996299744
# new_u = Array([0.8513324], dtype=float32)
# new_input = 0.851332426071167
#
#
# Iteration #59 at 6.0 seconds
# currstate= array([-0.19301912, -0.19474702]), currinput= 0.851332426071167
# ref = 0.49411353
# pred = Array([0.49855143], dtype=float32)
# ref = 0.49411353
# error = Array([1.96949e-05], dtype=float32)
# dgdu = Array([0.00768314], dtype=float32)
# hess = Array([1.5009297], dtype=float32)
# d2gdu2_inv = Array([0.66625375], dtype=float32)
# scaling = Array([0.00511892], dtype=float32)
# udot = Array([-0.10237836], dtype=float32)
# change_u = Array([-0.01023784], dtype=float32)
# currinput = 0.851332426071167
# new_u = Array([0.8410946], dtype=float32)
# new_input = 0.8410946130752563
#
#
# Iteration #60 at 6.099999904632568 seconds
# currstate= array([-0.10831601, -0.11071129]), currinput= 0.8410946130752563
# ref = 0.57843983
# pred = Array([0.5869051], dtype=float32)
# ref = 0.57843983
# error = Array([7.166114e-05], dtype=float32)
# dgdu = Array([0.01535043], dtype=float32)
# hess = Array([1.6501257], dtype=float32)
# d2gdu2_inv = Array([0.60601443], dtype=float32)
# scaling = Array([0.00930258], dtype=float32)
# udot = Array([-0.1860516], dtype=float32)
# change_u = Array([-0.01860516], dtype=float32)
# currinput = 0.8410946130752563
# new_u = Array([0.82248944], dtype=float32)
# new_input = 0.8224894404411316
#
#
# Iteration #61 at 6.199999809265137 seconds
# currstate= array([-0.02459431, -0.02782316]), currinput= 0.8224894404411316
# ref = 0.6569866
# pred = Array([0.6725264], dtype=float32)
# ref = 0.6569866
# error = Array([0.00024149], dtype=float32)
# dgdu = Array([0.02983037], dtype=float32)
# hess = Array([1.8570021], dtype=float32)
# d2gdu2_inv = Array([0.53850234], dtype=float32)
# scaling = Array([0.01606373], dtype=float32)
# udot = Array([-0.32127452], dtype=float32)
# change_u = Array([-0.03212745], dtype=float32)
# currinput = 0.8224894404411316
# new_u = Array([0.790362], dtype=float32)
# new_input = 0.7903620004653931
#
#
# Iteration #62 at 6.300000190734863 seconds
# currstate= array([0.05827133, 0.05545628]), currinput= 0.7903620004653931
# ref = 0.72896934
# pred = Array([0.75269073], dtype=float32)
# ref = 0.72896934
# error = Array([0.0005627], dtype=float32)
# dgdu = Array([0.04861481], dtype=float32)
# hess = Array([2.1285064], dtype=float32)
# d2gdu2_inv = Array([0.46981302], dtype=float32)
# scaling = Array([0.02283987], dtype=float32)
# udot = Array([-0.45679745], dtype=float32)
# change_u = Array([-0.04567974], dtype=float32)
# currinput = 0.7903620004653931
# new_u = Array([0.74468225], dtype=float32)
# new_input = 0.744682252407074
#
#
# Iteration #63 at 6.400000095367432 seconds
# currstate= array([0.1376273, 0.1355404]), currinput= 0.744682252407074
# ref = 0.79366803
# pred = Array([0.82400876], dtype=float32)
# ref = 0.79366803
# error = Array([0.00092056], dtype=float32)
# dgdu = Array([0.06659809], dtype=float32)
# hess = Array([2.4544587], dtype=float32)
# d2gdu2_inv = Array([0.4074218], dtype=float32)
# scaling = Array([0.02713351], dtype=float32)
# udot = Array([-0.54267025], dtype=float32)
# change_u = Array([-0.05426703], dtype=float32)
# currinput = 0.744682252407074
# new_u = Array([0.6904152], dtype=float32)
# new_input = 0.6904152035713196
#
#
# Iteration #64 at 6.5 seconds
# currstate= array([0.21266696, 0.20989639]), currinput= 0.6904152035713196
# ref = 0.85043675
# pred = Array([0.8890289], dtype=float32)
# ref = 0.85043675
# error = Array([0.00148935], dtype=float32)
# dgdu = Array([0.09083316], dtype=float32)
# hess = Array([2.8405993], dtype=float32)
# d2gdu2_inv = Array([0.35203838], dtype=float32)
# scaling = Array([0.03197676], dtype=float32)
# udot = Array([-0.6395352], dtype=float32)
# change_u = Array([-0.06395352], dtype=float32)
# currinput = 0.6904152035713196
# new_u = Array([0.6264617], dtype=float32)
# new_input = 0.6264616847038269
#
#
# Iteration #65 at 6.599999904632568 seconds
# currstate= array([0.28364167, 0.27868769]), currinput= 0.6264616847038269
# ref = 0.8987081
# pred = Array([0.94533443], dtype=float32)
# ref = 0.8987081
# error = Array([0.00217401], dtype=float32)
# dgdu = Array([0.11743338], dtype=float32)
# hess = Array([3.274199], dtype=float32)
# d2gdu2_inv = Array([0.30541822], dtype=float32)
# scaling = Array([0.03586629], dtype=float32)
# udot = Array([-0.71732587], dtype=float32)
# change_u = Array([-0.07173259], dtype=float32)
# currinput = 0.6264616847038269
# new_u = Array([0.5547291], dtype=float32)
# new_input = 0.5547291040420532
#
#
# Iteration #66 at 6.699999809265137 seconds
# currstate= array([0.34627837, 0.34268346]), currinput= 0.5547291040420532
# ref = 0.93799996
# pred = Array([0.98817354], dtype=float32)
# ref = 0.93799996
# error = Array([0.00251739], dtype=float32)
# dgdu = Array([0.13443676], dtype=float32)
# hess = Array([3.718564], dtype=float32)
# d2gdu2_inv = Array([0.26892102], dtype=float32)
# scaling = Array([0.03615287], dtype=float32)
# udot = Array([-0.7230574], dtype=float32)
# change_u = Array([-0.07230574], dtype=float32)
# currinput = 0.5547291040420532
# new_u = Array([0.48242337], dtype=float32)
# new_input = 0.4824233651161194
#
#
# Iteration #67 at 6.800000190734863 seconds
# currstate= array([0.40501323, 0.40230817]), currinput= 0.4824233651161194
# ref = 0.96791977
# pred = Array([1.0311557], dtype=float32)
# ref = 0.96791977
# error = Array([0.00399878], dtype=float32)
# dgdu = Array([0.1805921], dtype=float32)
# hess = Array([4.26726], dtype=float32)
# d2gdu2_inv = Array([0.23434241], dtype=float32)
# scaling = Array([0.04232039], dtype=float32)
# udot = Array([-0.8464078], dtype=float32)
# change_u = Array([-0.08464078], dtype=float32)
# currinput = 0.4824233651161194
# new_u = Array([0.3977826], dtype=float32)
# new_input = 0.3977825939655304
#
#
# Iteration #68 at 6.900000095367432 seconds
# currstate= array([0.46205288, 0.4557915 ]), currinput= 0.3977825939655304
# ref = 0.9881683
# pred = Array([1.0569504], dtype=float32)
# ref = 0.9881683
# error = Array([0.00473098], dtype=float32)
# dgdu = Array([0.20671286], dtype=float32)
# hess = Array([4.74888], dtype=float32)
# d2gdu2_inv = Array([0.21057597], dtype=float32)
# scaling = Array([0.04352876], dtype=float32)
# udot = Array([-0.87057525], dtype=float32)
# change_u = Array([-0.08705752], dtype=float32)
# currinput = 0.3977825939655304
# new_u = Array([0.31072506], dtype=float32)
# new_input = 0.31072506308555603
#
#
# Iteration #69 at 7.0 seconds
# currstate= array([0.51133239, 0.50518382]), currinput= 0.31072506308555603
# ref = 0.9985434
# pred = Array([1.0698332], dtype=float32)
# ref = 0.9985434
# error = Array([0.00508223], dtype=float32)
# dgdu = Array([0.22338219], dtype=float32)
# hess = Array([5.1755395], dtype=float32)
# d2gdu2_inv = Array([0.19321658], dtype=float32)
# scaling = Array([0.04316114], dtype=float32)
# udot = Array([-0.86322284], dtype=float32)
# change_u = Array([-0.08632229], dtype=float32)
# currinput = 0.31072506308555603
# new_u = Array([0.22440279], dtype=float32)
# new_input = 0.2244027853012085
#
#
# Iteration #70 at 7.099999904632568 seconds
# currstate= array([0.55532736, 0.55131274]), currinput= 0.2244027853012085
# ref = 0.99894136
# pred = Array([1.0773714], dtype=float32)
# ref = 0.99894136
# error = Array([0.00615126], dtype=float32)
# dgdu = Array([0.25517827], dtype=float32)
# hess = Array([5.6125164], dtype=float32)
# d2gdu2_inv = Array([0.1781732], dtype=float32)
# scaling = Array([0.04546593], dtype=float32)
# udot = Array([-0.90931857], dtype=float32)
# change_u = Array([-0.09093186], dtype=float32)
# currinput = 0.2244027853012085
# new_u = Array([0.13347092], dtype=float32)
# new_input = 0.13347092270851135
#
#
# Iteration #71 at 7.199999809265137 seconds
# currstate= array([0.59385693, 0.58908594]), currinput= 0.13347092270851135
# ref = 0.98935825
# pred = Array([1.059983], dtype=float32)
# ref = 0.98935825
# error = Array([0.00498786], dtype=float32)
# dgdu = Array([0.23310469], dtype=float32)
# hess = Array([5.746323], dtype=float32)
# d2gdu2_inv = Array([0.17402433], dtype=float32)
# scaling = Array([0.04056589], dtype=float32)
# udot = Array([-0.8113177], dtype=float32)
# change_u = Array([-0.08113177], dtype=float32)
# currinput = 0.13347092270851135
# new_u = Array([0.05233915], dtype=float32)
# new_input = 0.05233915150165558
#
#
# Iteration #72 at 7.300000190734863 seconds
# currstate= array([0.62888908, 0.62390459]), currinput= 0.05233915150165558
# ref = 0.9698897
# pred = Array([1.0514206], dtype=float32)
# ref = 0.9698897
# error = Array([0.00664728], dtype=float32)
# dgdu = Array([0.27458388], dtype=float32)
# hess = Array([6.0344176], dtype=float32)
# d2gdu2_inv = Array([0.16571607], dtype=float32)
# scaling = Array([0.04550296], dtype=float32)
# udot = Array([-0.9100592], dtype=float32)
# change_u = Array([-0.09100592], dtype=float32)
# currinput = 0.05233915150165558
# new_u = Array([-0.03866677], dtype=float32)
# new_input = -0.03866676986217499
#
#
# Iteration #73 at 7.400000095367432 seconds
# currstate= array([0.65863913, 0.65365911]), currinput= -0.03866676986217499
# ref = 0.94073063
# pred = Array([1.0104358], dtype=float32)
# ref = 0.94073063
# error = Array([0.00485881], dtype=float32)
# dgdu = Array([0.23277907], dtype=float32)
# hess = Array([5.8837857], dtype=float32)
# d2gdu2_inv = Array([0.1699586], dtype=float32)
# scaling = Array([0.03956281], dtype=float32)
# udot = Array([-0.7912561], dtype=float32)
# change_u = Array([-0.07912561], dtype=float32)
# currinput = -0.03866676986217499
# new_u = Array([-0.11779238], dtype=float32)
# new_input = -0.11779238283634186
#
#
# Iteration #74 at 7.5 seconds
# currstate= array([0.68271524, 0.6772058 ]), currinput= -0.11779238283634186
# ref = 0.90217173
# pred = Array([0.96934897], dtype=float32)
# ref = 0.90217173
# error = Array([0.00451278], dtype=float32)
# dgdu = Array([0.22141477], dtype=float32)
# hess = Array([5.7223525], dtype=float32)
# d2gdu2_inv = Array([0.17475331], dtype=float32)
# scaling = Array([0.03869297], dtype=float32)
# udot = Array([-0.7738593], dtype=float32)
# change_u = Array([-0.07738593], dtype=float32)
# currinput = -0.11779238283634186
# new_u = Array([-0.19517832], dtype=float32)
# new_input = -0.1951783150434494
#
#
# Iteration #75 at 7.599999904632568 seconds
# currstate= array([0.70086902, 0.69620043]), currinput= -0.1951783150434494
# ref = 0.85459906
# pred = Array([0.91324866], dtype=float32)
# ref = 0.85459906
# error = Array([0.00343978], dtype=float32)
# dgdu = Array([0.18779267], dtype=float32)
# hess = Array([5.3661847], dtype=float32)
# d2gdu2_inv = Array([0.18635213], dtype=float32)
# scaling = Array([0.03499557], dtype=float32)
# udot = Array([-0.69991136], dtype=float32)
# change_u = Array([-0.06999113], dtype=float32)
# currinput = -0.1951783150434494
# new_u = Array([-0.26516944], dtype=float32)
# new_input = -0.2651694416999817
#
#
# Iteration #76 at 7.699999809265137 seconds
# currstate= array([0.71525252, 0.71173942]), currinput= -0.2651694416999817
# ref = 0.7984871
# pred = Array([0.8576111], dtype=float32)
# ref = 0.7984871
# error = Array([0.00349565], dtype=float32)
# dgdu = Array([0.18344924], dtype=float32)
# hess = Array([5.0405674], dtype=float32)
# d2gdu2_inv = Array([0.19839036], dtype=float32)
# scaling = Array([0.03639456], dtype=float32)
# udot = Array([-0.72789127], dtype=float32)
# change_u = Array([-0.07278913], dtype=float32)
# currinput = -0.2651694416999817
# new_u = Array([-0.33795857], dtype=float32)
# new_input = -0.33795857429504395
#
#
# Iteration #77 at 7.800000190734863 seconds
# currstate= array([0.7243396 , 0.72285396]), currinput= -0.33795857429504395
# ref = 0.7343968
# pred = Array([0.7827474], dtype=float32)
# ref = 0.7343968
# error = Array([0.00233778], dtype=float32)
# dgdu = Array([0.1426459], dtype=float32)
# hess = Array([4.5181947], dtype=float32)
# d2gdu2_inv = Array([0.22132733], dtype=float32)
# scaling = Array([0.03157144], dtype=float32)
# udot = Array([-0.6314287], dtype=float32)
# change_u = Array([-0.06314287], dtype=float32)
# currinput = -0.33795857429504395
# new_u = Array([-0.40110144], dtype=float32)
# new_input = -0.4011014401912689
#
#
# Iteration #78 at 7.900000095367432 seconds
# currstate= array([0.72654456, 0.72751909]), currinput= -0.4011014401912689
# ref = 0.6629694
# pred = Array([0.7033106], dtype=float32)
# ref = 0.6629694
# error = Array([0.00162741], dtype=float32)
# dgdu = Array([0.11223359], dtype=float32)
# hess = Array([3.9910116], dtype=float32)
# d2gdu2_inv = Array([0.25056303], dtype=float32)
# scaling = Array([0.02812159], dtype=float32)
# udot = Array([-0.56243175], dtype=float32)
# change_u = Array([-0.05624318], dtype=float32)
# currinput = -0.4011014401912689
# new_u = Array([-0.45734462], dtype=float32)
# new_input = -0.4573446214199066
#
#
# Iteration #79 at 8.0 seconds
# currstate= array([0.72470844, 0.72531343]), currinput= -0.4573446214199066
# ref = 0.58491707
# pred = Array([0.62149364], dtype=float32)
# ref = 0.58491707
# error = Array([0.00133785], dtype=float32)
# dgdu = Array([0.09543393], dtype=float32)
# hess = Array([3.4973516], dtype=float32)
# d2gdu2_inv = Array([0.28593063], dtype=float32)
# scaling = Array([0.02728748], dtype=float32)
# udot = Array([-0.54574966], dtype=float32)
# change_u = Array([-0.05457497], dtype=float32)
# currinput = -0.4573446214199066
# new_u = Array([-0.5119196], dtype=float32)
# new_input = -0.5119196176528931
#
#
# Iteration #80 at 8.100000381469727 seconds
# currstate= array([0.71757197, 0.71679085]), currinput= -0.5119196176528931
# ref = 0.5010204
# pred = Array([0.53154194], dtype=float32)
# ref = 0.5010204
# error = Array([0.00093157], dtype=float32)
# dgdu = Array([0.07408016], dtype=float32)
# hess = Array([3.0096962], dtype=float32)
# d2gdu2_inv = Array([0.33225945], dtype=float32)
# scaling = Array([0.02461383], dtype=float32)
# udot = Array([-0.49227667], dtype=float32)
# change_u = Array([-0.04922767], dtype=float32)
# currinput = -0.5119196176528931
# new_u = Array([-0.5611473], dtype=float32)
# new_input = -0.5611472725868225
#
#
# Iteration #81 at 8.200000762939453 seconds
# currstate= array([0.70144039, 0.70382291]), currinput= -0.5611472725868225
# ref = 0.4121176
# pred = Array([0.43763617], dtype=float32)
# ref = 0.4121176
# error = Array([0.0006512], dtype=float32)
# dgdu = Array([0.05753675], dtype=float32)
# hess = Array([2.5846972], dtype=float32)
# d2gdu2_inv = Array([0.3868925], dtype=float32)
# scaling = Array([0.02226054], dtype=float32)
# udot = Array([-0.44521075], dtype=float32)
# change_u = Array([-0.04452107], dtype=float32)
# currinput = -0.5611472725868225
# new_u = Array([-0.60566837], dtype=float32)
# new_input = -0.6056683659553528
#
#
# Iteration #82 at 8.300000190734863 seconds
# currstate= array([0.67960459, 0.68273407]), currinput= -0.6056683659553528
# ref = 0.319098
# pred = Array([0.3423178], dtype=float32)
# ref = 0.319098
# error = Array([0.00053916], dtype=float32)
# dgdu = Array([0.04866908], dtype=float32)
# hess = Array([2.226851], dtype=float32)
# d2gdu2_inv = Array([0.4490646], dtype=float32)
# scaling = Array([0.02185556], dtype=float32)
# udot = Array([-0.43711126], dtype=float32)
# change_u = Array([-0.04371113], dtype=float32)
# currinput = -0.6056683659553528
# new_u = Array([-0.6493795], dtype=float32)
# new_input = -0.6493794918060303
#
#
# Iteration #83 at 8.40000057220459 seconds
# currstate= array([0.6504705 , 0.65496993]), currinput= -0.6493794918060303
# ref = 0.22288917
# pred = Array([0.24310488], dtype=float32)
# ref = 0.22288917
# error = Array([0.00040867], dtype=float32)
# dgdu = Array([0.03952394], dtype=float32)
# hess = Array([1.9307898], dtype=float32)
# d2gdu2_inv = Array([0.51792276], dtype=float32)
# scaling = Array([0.02047035], dtype=float32)
# udot = Array([-0.40940696], dtype=float32)
# change_u = Array([-0.0409407], dtype=float32)
# currinput = -0.6493794918060303
# new_u = Array([-0.6903202], dtype=float32)
# new_input = -0.6903201937675476
#
#
# Iteration #84 at 8.500000953674316 seconds
# currstate= array([0.6157105 , 0.61559647]), currinput= -0.6903201937675476
# ref = 0.12445329
# pred = Array([0.14310546], dtype=float32)
# ref = 0.12445329
# error = Array([0.0003479], dtype=float32)
# dgdu = Array([0.03420182], dtype=float32)
# hess = Array([1.6938038], dtype=float32)
# d2gdu2_inv = Array([0.59038717], dtype=float32)
# scaling = Array([0.02019231], dtype=float32)
# udot = Array([-0.40384626], dtype=float32)
# change_u = Array([-0.04038463], dtype=float32)
# currinput = -0.6903201937675476
# new_u = Array([-0.73070484], dtype=float32)
# new_input = -0.7307048439979553
#
#
# Iteration #85 at 8.600000381469727 seconds
# currstate= array([0.56937253, 0.56916165]), currinput= -0.7307048439979553
# ref = 0.024774853
# pred = Array([0.03811747], dtype=float32)
# ref = 0.024774853
# error = Array([0.00017803], dtype=float32)
# dgdu = Array([0.0232044], dtype=float32)
# hess = Array([1.5179992], dtype=float32)
# d2gdu2_inv = Array([0.65876186], dtype=float32)
# scaling = Array([0.01528617], dtype=float32)
# udot = Array([-0.30572343], dtype=float32)
# change_u = Array([-0.03057234], dtype=float32)
# currinput = -0.7307048439979553
# new_u = Array([-0.7612772], dtype=float32)
# new_input = -0.7612771987915039
#
#
# Iteration #86 at 8.700000762939453 seconds
# currstate= array([0.51372945, 0.51421058]), currinput= -0.7612771987915039
# ref = -0.07515207
# pred = Array([-0.06174691], dtype=float32)
# ref = -0.07515207
# error = Array([0.0001797], dtype=float32)
# dgdu = Array([0.02246879], dtype=float32)
# hess = Array([1.4077684], dtype=float32)
# d2gdu2_inv = Array([0.71034414], dtype=float32)
# scaling = Array([0.01596057], dtype=float32)
# udot = Array([-0.31921142], dtype=float32)
# change_u = Array([-0.03192114], dtype=float32)
# currinput = -0.7612771987915039
# new_u = Array([-0.79319835], dtype=float32)
# new_input = -0.7931983470916748
#
#
# Iteration #87 at 8.800000190734863 seconds
# currstate= array([0.4517976 , 0.45131788]), currinput= -0.7931983470916748
# ref = -0.17432716
# pred = Array([-0.16354996], dtype=float32)
# ref = -0.17432716
# error = Array([0.00011615], dtype=float32)
# dgdu = Array([0.01768406], dtype=float32)
# hess = Array([1.3467592], dtype=float32)
# d2gdu2_inv = Array([0.74252325], dtype=float32)
# scaling = Array([0.01313083], dtype=float32)
# udot = Array([-0.26261654], dtype=float32)
# change_u = Array([-0.02626166], dtype=float32)
# currinput = -0.7931983470916748
# new_u = Array([-0.81946], dtype=float32)
# new_input = -0.8194599747657776
#
#
# Iteration #88 at 8.90000057220459 seconds
# currstate= array([0.38261646, 0.38051   ]), currinput= -0.8194599747657776
# ref = -0.27176136
# pred = Array([-0.263882], dtype=float32)
# ref = -0.27176136
# error = Array([6.20841e-05], dtype=float32)
# dgdu = Array([0.01288005], dtype=float32)
# hess = Array([1.3351247], dtype=float32)
# d2gdu2_inv = Array([0.7489937], dtype=float32)
# scaling = Array([0.00964707], dtype=float32)
# udot = Array([-0.19294146], dtype=float32)
# change_u = Array([-0.01929415], dtype=float32)
# currinput = -0.8194599747657776
# new_u = Array([-0.8387541], dtype=float32)
# new_input = -0.8387541174888611
#
#
# Iteration #89 at 9.000000953674316 seconds
# currstate= array([0.3067334 , 0.30375487]), currinput= -0.8387541174888611
# ref = -0.3664802
# pred = Array([-0.36314577], dtype=float32)
# ref = -0.3664802
# error = Array([1.1118443e-05], dtype=float32)
# dgdu = Array([0.0055256], dtype=float32)
# hess = Array([1.3721044], dtype=float32)
# d2gdu2_inv = Array([0.7288075], dtype=float32)
# scaling = Array([0.0040271], dtype=float32)
# udot = Array([-0.08054194], dtype=float32)
# change_u = Array([-0.00805419], dtype=float32)
# currinput = -0.8387541174888611
# new_u = Array([-0.8468083], dtype=float32)
# new_input = -0.8468083143234253
#
#
# Iteration #90 at 9.100000381469727 seconds
# currstate= array([0.22524197, 0.22284138]), currinput= -0.8468083143234253
# ref = -0.4575364
# pred = Array([-0.4591954], dtype=float32)
# ref = -0.4575364
# error = Array([2.7523006e-06], dtype=float32)
# dgdu = Array([-0.00283073], dtype=float32)
# hess = Array([1.4564457], dtype=float32)
# d2gdu2_inv = Array([0.686603], dtype=float32)
# scaling = Array([-0.00194359], dtype=float32)
# udot = Array([0.03887175], dtype=float32)
# change_u = Array([0.00388718], dtype=float32)
# currinput = -0.8468083143234253
# new_u = Array([-0.84292114], dtype=float32)
# new_input = -0.8429211378097534
#
#
# Iteration #91 at 9.200000762939453 seconds
# currstate= array([0.14158241, 0.13770565]), currinput= -0.8429211378097534
# ref = -0.5440219
# pred = Array([-0.5505611], dtype=float32)
# ref = -0.5440219
# error = Array([4.276069e-05], dtype=float32)
# dgdu = Array([-0.0116533], dtype=float32)
# hess = Array([1.5920885], dtype=float32)
# d2gdu2_inv = Array([0.6281058], dtype=float32)
# scaling = Array([-0.00731951], dtype=float32)
# udot = Array([0.14639014], dtype=float32)
# change_u = Array([0.01463901], dtype=float32)
# currinput = -0.8429211378097534
# new_u = Array([-0.8282821], dtype=float32)
# new_input = -0.8282821178436279
#
#
# Iteration #92 at 9.300000190734863 seconds
# currstate= array([0.05609132, 0.05279477]), currinput= -0.8282821178436279
# ref = -0.6250709
# pred = Array([-0.63972497], dtype=float32)
# ref = -0.6250709
# error = Array([0.00021474], dtype=float32)
# dgdu = Array([-0.02758988], dtype=float32)
# hess = Array([1.7849321], dtype=float32)
# d2gdu2_inv = Array([0.5602454], dtype=float32)
# scaling = Array([-0.0154571], dtype=float32)
# udot = Array([0.30914208], dtype=float32)
# change_u = Array([0.03091421], dtype=float32)
# currinput = -0.8282821178436279
# new_u = Array([-0.79736793], dtype=float32)
# new_input = -0.7973679304122925
#
#
# Iteration #93 at 9.40000057220459 seconds
# currstate= array([-0.02667427, -0.02886248]), currinput= -0.7973679304122925
# ref = -0.69987524
# pred = Array([-0.7174454], dtype=float32)
# ref = -0.69987524
# error = Array([0.00030871], dtype=float32)
# dgdu = Array([-0.03510605], dtype=float32)
# hess = Array([2.0153084], dtype=float32)
# d2gdu2_inv = Array([0.49620196], dtype=float32)
# scaling = Array([-0.01741969], dtype=float32)
# udot = Array([0.34839386], dtype=float32)
# change_u = Array([0.03483939], dtype=float32)
# currinput = -0.7973679304122925
# new_u = Array([-0.76252854], dtype=float32)
# new_input = -0.7625285387039185
#
#
# Iteration #94 at 9.500000953674316 seconds
# currstate= array([-0.10540452, -0.10616732]), currinput= -0.7625285387039185
# ref = -0.76768655
# pred = Array([-0.7944308], dtype=float32)
# ref = -0.76768655
# error = Array([0.00071525], dtype=float32)
# dgdu = Array([-0.05713265], dtype=float32)
# hess = Array([2.3185444], dtype=float32)
# d2gdu2_inv = Array([0.43130508], dtype=float32)
# scaling = Array([-0.0246416], dtype=float32)
# udot = Array([0.49283203], dtype=float32)
# change_u = Array([0.0492832], dtype=float32)
# currinput = -0.7625285387039185
# new_u = Array([-0.71324533], dtype=float32)
# new_input = -0.7132453322410583
#
#
# Iteration #95 at 9.600000381469727 seconds
# currstate= array([-0.18160816, -0.18314977]), currinput= -0.7132453322410583
# ref = -0.8278268
# pred = Array([-0.8635443], dtype=float32)
# ref = -0.8278268
# error = Array([0.00127574], dtype=float32)
# dgdu = Array([-0.08190197], dtype=float32)
# hess = Array([2.6896865], dtype=float32)
# d2gdu2_inv = Array([0.37179053], dtype=float32)
# scaling = Array([-0.03045038], dtype=float32)
# udot = Array([0.6090076], dtype=float32)
# change_u = Array([0.06090076], dtype=float32)
# currinput = -0.7132453322410583
# new_u = Array([-0.6523446], dtype=float32)
# new_input = -0.6523445844650269
#
#
# Iteration #96 at 9.700000762939453 seconds
# currstate= array([-0.25396231, -0.25522649]), currinput= -0.6523445844650269
# ref = -0.8796962
# pred = Array([-0.9232769], dtype=float32)
# ref = -0.8796962
# error = Array([0.00189928], dtype=float32)
# dgdu = Array([-0.10710741], dtype=float32)
# hess = Array([3.109593], dtype=float32)
# d2gdu2_inv = Array([0.3215855], dtype=float32)
# scaling = Array([-0.03444419], dtype=float32)
# udot = Array([0.6888838], dtype=float32)
# change_u = Array([0.06888838], dtype=float32)
# currinput = -0.6523445844650269
# new_u = Array([-0.5834562], dtype=float32)
# new_input = -0.5834562182426453
#
#
# Iteration #97 at 9.800000190734863 seconds
# currstate= array([-0.3216781, -0.3236537]), currinput= -0.5834562182426453
# ref = -0.92277557
# pred = Array([-0.9763216], dtype=float32)
# ref = -0.92277557
# error = Array([0.00286718], dtype=float32)
# dgdu = Array([-0.14101125], dtype=float32)
# hess = Array([3.5987675], dtype=float32)
# d2gdu2_inv = Array([0.27787292], dtype=float32)
# scaling = Array([-0.03918321], dtype=float32)
# udot = Array([0.7836641], dtype=float32)
# change_u = Array([0.07836641], dtype=float32)
# currinput = -0.5834562182426453
# new_u = Array([-0.5050898], dtype=float32)
# new_input = -0.5050898194313049
#
#
# Iteration #98 at 9.90000057220459 seconds
# currstate= array([-0.38430253, -0.38523087]), currinput= -0.5050898194313049
# ref = -0.95663524
# pred = Array([-1.0149974], dtype=float32)
# ref = -0.95663524
# error = Array([0.00340614], dtype=float32)
# dgdu = Array([-0.16318834], dtype=float32)
# hess = Array([4.0750403], dtype=float32)
# d2gdu2_inv = Array([0.24539635], dtype=float32)
# scaling = Array([-0.04004582], dtype=float32)
# udot = Array([0.80091643], dtype=float32)
# change_u = Array([0.08009165], dtype=float32)
# currinput = -0.5050898194313049
# new_u = Array([-0.42499816], dtype=float32)
# new_input = -0.4249981641769409

# %%
ts = np.arange(0, T, SIM_STEP)
x1s = states[:,0]
x2s = states[:,1]
# x3s = states[:,2]

r1s = refs[:,0]
# r2s = refs[:,1]
# r3s = refs[:,2]

# %%
#make figure 1

plt.figure(1)
plt.plot(ts, x1s, label="y")
plt.plot(ts, r1s, label="ref")
plt.title("Output & Reference v Time")
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.legend()

# %%
refs
# Out:
# array([[ 0.71735609],
#        [ 0.09983342],
#        [ 0.19866933],
#        [ 0.29552022],
#        [ 0.38941833],
#        [ 0.47942555],
#        [ 0.56464249],
#        [ 0.64421773],
#        [ 0.71735609],
#        [ 0.78332692],
#        [ 0.84147102],
#        [ 0.89120734],
#        [ 0.93203908],
#        [ 0.9635582 ],
#        [ 0.98544973],
#        [ 0.997495  ],
#        [ 0.99957359],
#        [ 0.99166483],
#        [ 0.97384763],
#        [ 0.94630009],
#        [ 0.90929741],
#        [ 0.86320943],
#        [ 0.80849636],
#        [ 0.74570525],
#        [ 0.67546332],
#        [ 0.59847218],
#        [ 0.5155015 ],
#        [ 0.42737985],
#        [ 0.33498821],
#        [ 0.23924947],
#        [ 0.14112   ],
#        [ 0.04158076],
#        [-0.05837419],
#        [-0.15774564],
#        [-0.25554097],
#        [-0.35078323],
#        [-0.44252035],
#        [-0.52983618],
#        [-0.61185783],
#        [-0.68776602],
#        [-0.7568025 ],
#        [-0.81827706],
#        [-0.87157565],
#        [-0.91616601],
#        [-0.9516021 ],
#        [-0.97753012],
#        [-0.99369097],
#        [-0.99992323],
#        [-0.99616462],
#        [-0.98245257],
#        [-0.95892429],
#        [-0.92581475],
#        [-0.88345474],
#        [-0.83226734],
#        [-0.77276444],
#        [-0.7055403 ],
#        [-0.63126671],
#        [-0.5506857 ],
#        [-0.46460202],
#        [-0.37387657],
#        [-0.27941549],
#        [-0.1821626 ],
#        [-0.0830896 ],
#        [ 0.01681409],
#        [ 0.1165493 ],
#        [ 0.21511999],
#        [ 0.31154129],
#        [ 0.40484974],
#        [ 0.49411353],
#        [ 0.57843983],
#        [ 0.65698659],
#        [ 0.72896898],
#        [ 0.79366773],
#        [ 0.85043675],
#        [ 0.89870811],
#        [ 0.93799996],
#        [ 0.96791965],
#        [ 0.98816818],
#        [ 0.99854338],
#        [ 0.99894136],
#        [ 0.98935825],
#        [ 0.9698897 ],
#        [ 0.94073027],
#        [ 0.90217173],
#        [ 0.85459858],
#        [ 0.79848653],
#        [ 0.73439682],
#        [ 0.6629687 ],
#        [ 0.58491707],
#        [ 0.50102037],
#        [ 0.4121176 ],
#        [ 0.319098  ],
#        [ 0.22288917],
#        [ 0.12445424],
#        [ 0.02477485],
#        [-0.07515207],
#        [-0.17432716],
#        [-0.27176136],
#        [-0.36647931],
#        [-0.4575364 ]])

# %%
np.sin(.1)
# Out:
# 0.09983341664682815

# %%
reference_function(0, [0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/factslabegmc/python_control/optimization_method_test.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/home/factslabegmc/python_control/optimization_method_test.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> reference_function(0, [0])
#
# NameError: name 'reference_function' is not defined

# %%
reference_function(0, [0])

# %%
len([0])
